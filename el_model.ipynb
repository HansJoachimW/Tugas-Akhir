# %%
import cv2
import random
import os
import numpy as np
from elpv_dataset.utils labelImg
import load_dataset
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
images, proba, types = load_dataset()

# %%
print(f"Number of images: {len(images)}")
print(f"Probability data: {proba.shape}")
print(f"Types: {len(types)}")
# Out:
# Number of images: 2624
# Probability data: (2624,)
# Types: 2624

# %%
random_index = random.randint(0, len(images) - 1)

# %%
random_image = images[random_index]
random_proba = proba[random_index]
random_type = types[random_index]

# %%
plt.imshow(random_image, cmap="gray")
plt.title(f"Type: {random_type}, Proba: {random_proba}")
plt.show()

# %%
print(set(types))
# Out:
# {'mono', 'poly'}

# %%
img_dataset = "el_img"
os.makedirs(img_dataset, exist_ok=True)

# %%
for idx, (image, label) in enumerate(zip(images, types)):
    image_path = os.path.join(img_dataset, f"image_{idx}.jpg")
    plt.imsave(image_path, image, cmap="gray")

# %%
annotated_dataset = "el_annotated"
os.makedirs(annotated_dataset, exist_ok=True)
